# %%
# %matplotlib widget
# %matplotlib inline
# %matplotlib ipympl
# Out:
# Warning: Cannot change to a different GUI toolkit: ipympl. Using widget instead.

# %%
import pandas as pd
from plotting_csv import *

# %%
file_name = 'results_[30-08-2023_20:00:28].csv'
df = pd.read_csv(file_name)
df['γ'] = df['p'] / df['n']

#Plot for λ vs MSE (fix μ and γ)
plot_param_vs_mse(df, 'λ', {'μ': 50, 'γ': 5})

# Plot for μ vs MSE (fix λ and γ)
plot_param_vs_mse(df, 'μ', {'λ': 50, 'γ': 5})

# Plot for γ vs MSE (fix λ and μ)
plot_param_vs_mse(df, 'γ', {'λ': 50, 'μ': 50})
# Out:
# 100
# 100
# 200
# <Axes: title={'center': "γ vs MSE (Nearest Fixed Params: [('λ', 50), ('μ', 50)]"}, xlabel='γ', ylabel='MSE'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
interative_bars_3d(df)
# Out:
# interactive(children=(Dropdown(description='x-axis', options=('μ', 'λ', 'γ'), value='μ'), Dropdown(description…

# %%
interative_bars_line(df)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='μ', min=1.0, step=1.98), FloatSlider(value=1.0, desc…
